# %% [markdown]
# <a href="https://colab.research.google.com/github/demolakstate/AdeNet-Deep-Learning-Architecture/blob/main/EfficientNetB7_earlystopping_fold_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# all_dataset_fold_1.zip  sample_data/

# %%
# !unzip all_dataset_fold_1.zip
# Out:
# Archive:  all_dataset_fold_1.zip
#    creating: all_dataset_fold_1/
#    creating: all_dataset_fold_1/train/
#    creating: all_dataset_fold_1/train/damaged/
#   inflating: all_dataset_fold_1/train/damaged/1777.JPG
#   inflating: all_dataset_fold_1/train/damaged/1656.JPG
#   inflating: all_dataset_fold_1/train/damaged/2834.JPG
#   inflating: all_dataset_fold_1/train/damaged/3217.JPG
#   inflating: all_dataset_fold_1/train/damaged/3330.JPG
#   inflating: all_dataset_fold_1/train/damaged/3845.JPG
#   inflating: all_dataset_fold_1/train/damaged/3677.JPG
#   inflating: all_dataset_fold_1/train/damaged/2702.JPG
#   inflating: all_dataset_fold_1/train/damaged/2680.JPG
#   inflating: all_dataset_fold_1/train/damaged/2865.JPG
#   inflating: all_dataset_fold_1/train/damaged/1834.JPG
#   inflating: all_dataset_fold_1/train/damaged/2819.JPG
#   inflating: all_dataset_fold_1/train/damaged/2759.JPG
#   inflating: all_dataset_fold_1/train/damaged/2888.JPG
#   inflating: all_dataset_fold_1/train/damaged/2412.JPG
#   inflating: all_dataset_fold_1/train/damaged/2461.JPG
#   inflating: all_dataset_fold_1/train/damaged/3514.JPG
#   inflating: all_dataset_fold_1/train/damaged/2806.JPG
#   inflating: all_dataset_fold_1/train/damaged/2898.JPG
#   inflating: all_dataset_fold_1/train/damaged/2669.JPG
#   inflating: all_dataset_fold_1/train/damaged/2065.JPG
#   inflating: all_dataset_fold_1/train/damaged/3013.JPG
#   inflating: all_dataset_fold_1/train/damaged/2927.JPG
#   inflating: all_dataset_fold_1/train/damaged/2440.JPG
#   inflating: all_dataset_fold_1/train/damaged/2765.JPG
#   inflating: all_dataset_fold_1/train/damaged/1051.JPG
#   inflating: all_dataset_fold_1/train/damaged/2260.JPG
#   inflating: all_dataset_fold_1/train/damaged/2422.JPG
#   inflating: all_dataset_fold_1/train/damaged/2581.JPG
#   inflating: all_dataset_fold_1/train/damaged/2490.JPG
#   inflating: all_dataset_fold_1/train/damaged/1258.JPG
#   inflating: all_dataset_fold_1/train/damaged/3076.JPG
#   inflating: all_dataset_fold_1/train/damaged/1172.JPG
#   inflating: all_dataset_fold_1/train/damaged/2924.JPG
#   inflating: all_dataset_fold_1/train/damaged/2283.JPG
#   inflating: all_dataset_fold_1/train/damaged/2429.JPG
#   inflating: all_dataset_fold_1/train/damaged/3070.JPG
#   inflating: all_dataset_fold_1/train/damaged/2965.JPG
#   inflating: all_dataset_fold_1/train/damaged/1946.JPG
#   inflating: all_dataset_fold_1/train/damaged/3198.JPG
#   inflating: all_dataset_fold_1/train/damaged/2100.JPG
#   inflating: all_dataset_fold_1/train/damaged/1929.JPG
#   inflating: all_dataset_fold_1/train/damaged/1370.JPG
#   inflating: all_dataset_fold_1/train/damaged/2853.JPG
#   inflating: all_dataset_fold_1/train/damaged/2549.JPG
#   inflating: all_dataset_fold_1/train/damaged/2692.JPG
#   inflating: all_dataset_fold_1/train/damaged/3633.JPG
#   inflating: all_dataset_fold_1/train/damaged/3642.JPG
#   inflating: all_dataset_fold_1/train/damaged/3009.JPG
#   inflating: all_dataset_fold_1/train/damaged/2796.JPG
#   inflating: all_dataset_fold_1/train/damaged/2976.JPG
#   inflating: all_dataset_fold_1/train/damaged/3820.JPG
#   inflating: all_dataset_fold_1/train/damaged/3023.JPG
#   inflating: all_dataset_fold_1/train/damaged/3232.JPG
#   inflating: all_dataset_fold_1/train/damaged/3615.JPG
#   inflating: all_dataset_fold_1/train/damaged/2822.JPG
#   inflating: all_dataset_fold_1/train/damaged/2561.JPG
#   inflating: all_dataset_fold_1/train/damaged/2564.JPG
#   inflating: all_dataset_fold_1/train/damaged/3029.JPG
#   inflating: all_dataset_fold_1/train/damaged/2371.JPG
#   inflating: all_dataset_fold_1/train/damaged/3605.JPG
#   inflating: all_dataset_fold_1/train/damaged/4653.JPG
#   inflating: all_dataset_fold_1/train/damaged/3150.JPG
#   inflating: all_dataset_fold_1/train/damaged/2955.JPG
#   inflating: all_dataset_fold_1/train/damaged/2612.JPG
#   inflating: all_dataset_fold_1/train/damaged/3964.JPG
#   inflating: all_dataset_fold_1/train/damaged/1673.JPG
#   inflating: all_dataset_fold_1/train/damaged/2792.JPG
#   inflating: all_dataset_fold_1/train/damaged/2203.JPG
#   inflating: all_dataset_fold_1/train/damaged/2209.JPG
#   inflating: all_dataset_fold_1/train/damaged/3224.JPG
#   inflating: all_dataset_fold_1/train/damaged/3287.JPG
#   inflating: all_dataset_fold_1/train/damaged/1865.JPG
#   inflating: all_dataset_fold_1/train/damaged/1769.JPG
#   inflating: all_dataset_fold_1/train/damaged/2408.JPG
#   inflating: all_dataset_fold_1/train/damaged/2008.JPG
#   inflating: all_dataset_fold_1/train/damaged/4767.JPG
#   inflating: all_dataset_fold_1/train/damaged/4597.JPG
#   inflating: all_dataset_fold_1/train/damaged/2007.JPG
#   inflating: all_dataset_fold_1/train/damaged/3398.JPG
#   inflating: all_dataset_fold_1/train/damaged/3440.JPG
#   inflating: all_dataset_fold_1/train/damaged/2605.JPG
#   inflating: all_dataset_fold_1/train/damaged/1220.JPG
#   inflating: all_dataset_fold_1/train/damaged/3047.JPG
#   inflating: all_dataset_fold_1/train/damaged/1090.JPG
#   inflating: all_dataset_fold_1/train/damaged/1879.JPG
#   inflating: all_dataset_fold_1/train/damaged/2687.JPG
#   inflating: all_dataset_fold_1/train/damaged/2445.JPG
#   inflating: all_dataset_fold_1/train/damaged/3182.JPG
#   inflating: all_dataset_fold_1/train/damaged/2998.JPG
#   inflating: all_dataset_fold_1/train/damaged/2365.JPG
#   inflating: all_dataset_fold_1/train/damaged/2168.JPG
#   inflating: all_dataset_fold_1/train/damaged/2653.JPG
#   inflating: all_dataset_fold_1/train/damaged/1496.JPG
#   inflating: all_dataset_fold_1/train/damaged/2758.JPG
#   inflating: all_dataset_fold_1/train/damaged/1017.JPG
#   inflating: all_dataset_fold_1/train/damaged/3554.JPG
#   inflating: all_dataset_fold_1/train/damaged/2831.JPG
#   inflating: all_dataset_fold_1/train/damaged/3195.JPG
#   inflating: all_dataset_fold_1/train/damaged/3532.JPG
#   inflating: all_dataset_fold_1/train/damaged/2536.JPG
#   inflating: all_dataset_fold_1/train/damaged/3566.JPG
#   inflating: all_dataset_fold_1/train/damaged/3631.JPG
#   inflating: all_dataset_fold_1/train/damaged/2905.JPG
#   inflating: all_dataset_fold_1/train/damaged/3527.JPG
#   inflating: all_dataset_fold_1/train/damaged/2719.JPG
#   inflating: all_dataset_fold_1/train/damaged/2413.JPG
#   inflating: all_dataset_fold_1/train/damaged/1601.JPG
#   inflating: all_dataset_fold_1/train/damaged/2741.JPG
#   inflating: all_dataset_fold_1/train/damaged/2855.JPG
#   inflating: all_dataset_fold_1/train/damaged/4260.JPG
#   inflating: all_dataset_fold_1/train/damaged/4634.JPG
#   inflating: all_dataset_fold_1/train/damaged/4203.JPG
#   inflating: all_dataset_fold_1/train/damaged/3209.JPG
#   inflating: all_dataset_fold_1/train/damaged/4083.JPG
#   inflating: all_dataset_fold_1/train/damaged/3321.JPG
#   inflating: all_dataset_fold_1/train/damaged/3424.JPG
#   inflating: all_dataset_fold_1/train/damaged/1516.JPG
#   inflating: all_dataset_fold_1/train/damaged/2801.JPG
#   inflating: all_dataset_fold_1/train/damaged/2444.JPG
#   inflating: all_dataset_fold_1/train/damaged/3163.JPG
#   inflating: all_dataset_fold_1/train/damaged/2456.JPG
#   inflating: all_dataset_fold_1/train/damaged/1967.JPG
#   inflating: all_dataset_fold_1/train/damaged/2262.JPG
#   inflating: all_dataset_fold_1/train/damaged/2402.JPG
#   inflating: all_dataset_fold_1/train/damaged/2411.JPG
#   inflating: all_dataset_fold_1/train/damaged/2919.JPG
#   inflating: all_dataset_fold_1/train/damaged/2115.JPG
#   inflating: all_dataset_fold_1/train/damaged/2810.JPG
#   inflating: all_dataset_fold_1/train/damaged/3905.JPG
#   inflating: all_dataset_fold_1/train/damaged/2775.JPG
#   inflating: all_dataset_fold_1/train/damaged/2345.JPG
#   inflating: all_dataset_fold_1/train/damaged/2972.JPG
#   inflating: all_dataset_fold_1/train/damaged/3203.JPG
#   inflating: all_dataset_fold_1/train/damaged/2766.JPG
#   inflating: all_dataset_fold_1/train/damaged/2682.JPG
#   inflating: all_dataset_fold_1/train/damaged/1249.JPG
#   inflating: all_dataset_fold_1/train/damaged/2390.JPG
#   inflating: all_dataset_fold_1/train/damaged/2261.JPG
#   inflating: all_dataset_fold_1/train/damaged/2762.JPG
#   inflating: all_dataset_fold_1/train/damaged/2548.JPG
#   inflating: all_dataset_fold_1/train/damaged/2193.JPG
#   inflating: all_dataset_fold_1/train/damaged/2914.JPG
#   inflating: all_dataset_fold_1/train/damaged/3709.JPG
#   inflating: all_dataset_fold_1/train/damaged/1952.JPG
#   inflating: all_dataset_fold_1/train/damaged/3056.JPG
#   inflating: all_dataset_fold_1/train/damaged/1176.JPG
#   inflating: all_dataset_fold_1/train/damaged/1039.JPG
#   inflating: all_dataset_fold_1/train/damaged/3133.JPG
#   inflating: all_dataset_fold_1/train/damaged/3736.JPG
#   inflating: all_dataset_fold_1/train/damaged/1727.JPG
#   inflating: all_dataset_fold_1/train/damaged/1770.JPG
#   inflating: all_dataset_fold_1/train/damaged/3004.JPG
#   inflating: all_dataset_fold_1/train/damaged/2829.JPG
#   inflating: all_dataset_fold_1/train/damaged/2025.JPG
#   inflating: all_dataset_fold_1/train/damaged/2075.JPG
#   inflating: all_dataset_fold_1/train/damaged/3022.JPG
#   inflating: all_dataset_fold_1/train/damaged/2663.JPG
#   inflating: all_dataset_fold_1/train/damaged/1262.JPG
#   inflating: all_dataset_fold_1/train/damaged/2828.JPG
#   inflating: all_dataset_fold_1/train/damaged/1713.JPG
#   inflating: all_dataset_fold_1/train/damaged/2378.JPG
#   inflating: all_dataset_fold_1/train/damaged/2239.JPG
#   inflating: all_dataset_fold_1/train/damaged/1676.JPG
#   inflating: all_dataset_fold_1/train/damaged/721.JPG
#   inflating: all_dataset_fold_1/train/damaged/2606.JPG
#   inflating: all_dataset_fold_1/train/damaged/2649.JPG
#   inflating: all_dataset_fold_1/train/damaged/3410.JPG
#   inflating: all_dataset_fold_1/train/damaged/3847.JPG
#   inflating: all_dataset_fold_1/train/damaged/3893.JPG
#   inflating: all_dataset_fold_1/train/damaged/3168.JPG
#   inflating: all_dataset_fold_1/train/damaged/2470.JPG
#   inflating: all_dataset_fold_1/train/damaged/4623.JPG
#   inflating: all_dataset_fold_1/train/damaged/4340.JPG
#   inflating: all_dataset_fold_1/train/damaged/1964.JPG
#   inflating: all_dataset_fold_1/train/damaged/3299.JPG
#   inflating: all_dataset_fold_1/train/damaged/2220.JPG
#   inflating: all_dataset_fold_1/train/damaged/2894.JPG
#   inflating: all_dataset_fold_1/train/damaged/2270.JPG
#   inflating: all_dataset_fold_1/train/damaged/1033.JPG
#   inflating: all_dataset_fold_1/train/damaged/2684.JPG
#   inflating: all_dataset_fold_1/train/damaged/1681.JPG
#   inflating: all_dataset_fold_1/train/damaged/1765.JPG
#   inflating: all_dataset_fold_1/train/damaged/3533.JPG
#   inflating: all_dataset_fold_1/train/damaged/2538.JPG
#   inflating: all_dataset_fold_1/train/damaged/4090.JPG
#   inflating: all_dataset_fold_1/train/damaged/2809.JPG
#   inflating: all_dataset_fold_1/train/damaged/2509.JPG
#   inflating: all_dataset_fold_1/train/damaged/2890.JPG
#   inflating: all_dataset_fold_1/train/damaged/3765.JPG
#   inflating: all_dataset_fold_1/train/damaged/2167.JPG
#   inflating: all_dataset_fold_1/train/damaged/3363.JPG
#   inflating: all_dataset_fold_1/train/damaged/2327.JPG
#   inflating: all_dataset_fold_1/train/damaged/2093.JPG
#   inflating: all_dataset_fold_1/train/damaged/1695.JPG
#   inflating: all_dataset_fold_1/train/damaged/2349.JPG
#   inflating: all_dataset_fold_1/train/damaged/1101.JPG
#   inflating: all_dataset_fold_1/train/damaged/1774.JPG
#   inflating: all_dataset_fold_1/train/damaged/2915.JPG
#   inflating: all_dataset_fold_1/train/damaged/3500.JPG
#   inflating: all_dataset_fold_1/train/damaged/1848.JPG
#   inflating: all_dataset_fold_1/train/damaged/1589.JPG
#   inflating: all_dataset_fold_1/train/damaged/2650.JPG
#   inflating: all_dataset_fold_1/train/damaged/2714.JPG
#   inflating: all_dataset_fold_1/train/damaged/2148.JPG
#   inflating: all_dataset_fold_1/train/damaged/1936.JPG
#   inflating: all_dataset_fold_1/train/damaged/2348.JPG
#   inflating: all_dataset_fold_1/train/damaged/2995.JPG
#   inflating: all_dataset_fold_1/train/damaged/3008.JPG
#   inflating: all_dataset_fold_1/train/damaged/1391.JPG
#   inflating: all_dataset_fold_1/train/damaged/2686.JPG
#   inflating: all_dataset_fold_1/train/damaged/2797.JPG
#   inflating: all_dataset_fold_1/train/damaged/2891.JPG
#   inflating: all_dataset_fold_1/train/damaged/1872.JPG
#   inflating: all_dataset_fold_1/train/damaged/1890.JPG
#   inflating: all_dataset_fold_1/train/damaged/2944.JPG
#   inflating: all_dataset_fold_1/train/damaged/2630.JPG
#   inflating: all_dataset_fold_1/train/damaged/1491.JPG
#   inflating: all_dataset_fold_1/train/damaged/3233.JPG
#   inflating: all_dataset_fold_1/train/damaged/1014.JPG
#   inflating: all_dataset_fold_1/train/damaged/3225.JPG
#   inflating: all_dataset_fold_1/train/damaged/3559.JPG
#   inflating: all_dataset_fold_1/train/damaged/3042.JPG
#   inflating: all_dataset_fold_1/train/damaged/3995.JPG
#   inflating: all_dataset_fold_1/train/damaged/2940.JPG
#   inflating: all_dataset_fold_1/train/damaged/2580.JPG
#   inflating: all_dataset_fold_1/train/damaged/2773.JPG
#   inflating: all_dataset_fold_1/train/damaged/3369.JPG
#   inflating: all_dataset_fold_1/train/damaged/3761.JPG
#   inflating: all_dataset_fold_1/train/damaged/2700.JPG
#   inflating: all_dataset_fold_1/train/damaged/2916.JPG
#   inflating: all_dataset_fold_1/train/damaged/3000.JPG
#   inflating: all_dataset_fold_1/train/damaged/4374.JPG
#   inflating: all_dataset_fold_1/train/damaged/2936.JPG
#   inflating: all_dataset_fold_1/train/damaged/3352.JPG
#   inflating: all_dataset_fold_1/train/damaged/3406.JPG
#   inflating: all_dataset_fold_1/train/damaged/3389.JPG
#   inflating: all_dataset_fold_1/train/damaged/582.JPG
#   inflating: all_dataset_fold_1/train/damaged/1357.JPG
#   inflating: all_dataset_fold_1/train/damaged/2713.JPG
#   inflating: all_dataset_fold_1/train/damaged/3603.JPG
#   inflating: all_dataset_fold_1/train/damaged/2728.JPG
#   inflating: all_dataset_fold_1/train/damaged/2003.JPG
#   inflating: all_dataset_fold_1/train/damaged/3206.JPG
#   inflating: all_dataset_fold_1/train/damaged/2308.JPG
#   inflating: all_dataset_fold_1/train/damaged/1708.JPG
#   inflating: all_dataset_fold_1/train/damaged/2563.JPG
#   inflating: all_dataset_fold_1/train/damaged/2344.JPG
#   inflating: all_dataset_fold_1/train/damaged/683.JPG
#   inflating: all_dataset_fold_1/train/damaged/2738.JPG
#   inflating: all_dataset_fold_1/train/damaged/2756.JPG
#   inflating: all_dataset_fold_1/train/damaged/4370.JPG
#   inflating: all_dataset_fold_1/train/damaged/1884.JPG
#   inflating: all_dataset_fold_1/train/damaged/2993.JPG
#   inflating: all_dataset_fold_1/train/damaged/4289.JPG
#   inflating: all_dataset_fold_1/train/damaged/3279.JPG
#   inflating: all_dataset_fold_1/train/damaged/2104.JPG
#   inflating: all_dataset_fold_1/train/damaged/2832.JPG
#   inflating: all_dataset_fold_1/train/damaged/1232.JPG
#   inflating: all_dataset_fold_1/train/damaged/3294.JPG
#   inflating: all_dataset_fold_1/train/damaged/2691.JPG
#   inflating: all_dataset_fold_1/train/damaged/1281.JPG
#   inflating: all_dataset_fold_1/train/damaged/2997.JPG
#   inflating: all_dataset_fold_1/train/damaged/2988.JPG
#   inflating: all_dataset_fold_1/train/damaged/1949.JPG
#   inflating: all_dataset_fold_1/train/damaged/1984.JPG
#   inflating: all_dataset_fold_1/train/damaged/3090.JPG
#   inflating: all_dataset_fold_1/train/damaged/2263.JPG
#   inflating: all_dataset_fold_1/train/damaged/2052.JPG
#   inflating: all_dataset_fold_1/train/damaged/2187.JPG
#   inflating: all_dataset_fold_1/train/damaged/1636.JPG
#   inflating: all_dataset_fold_1/train/damaged/2794.JPG
#   inflating: all_dataset_fold_1/train/damaged/2494.JPG
#   inflating: all_dataset_fold_1/train/damaged/2232.JPG
#   inflating: all_dataset_fold_1/train/damaged/2771.JPG
#   inflating: all_dataset_fold_1/train/damaged/4210.JPG
#   inflating: all_dataset_fold_1/train/damaged/2438.JPG
#   inflating: all_dataset_fold_1/train/damaged/3238.JPG
#   inflating: all_dataset_fold_1/train/damaged/2665.JPG
#   inflating: all_dataset_fold_1/train/damaged/2695.JPG
#   inflating: all_dataset_fold_1/train/damaged/2496.JPG
#   inflating: all_dataset_fold_1/train/damaged/1698.JPG
#   inflating: all_dataset_fold_1/train/damaged/2619.JPG
#   inflating: all_dataset_fold_1/train/damaged/2343.JPG
#   inflating: all_dataset_fold_1/train/damaged/3441.JPG
#   inflating: all_dataset_fold_1/train/damaged/1876.JPG
#   inflating: all_dataset_fold_1/train/damaged/3661.JPG
#   inflating: all_dataset_fold_1/train/damaged/2863.JPG
#   inflating: all_dataset_fold_1/train/damaged/4406.JPG
#   inflating: all_dataset_fold_1/train/damaged/2729.JPG
#   inflating: all_dataset_fold_1/train/damaged/2880.JPG
#   inflating: all_dataset_fold_1/train/damaged/3502.JPG
#   inflating: all_dataset_fold_1/train/damaged/3878.JPG
#   inflating: all_dataset_fold_1/train/damaged/1379.JPG
#   inflating: all_dataset_fold_1/train/damaged/4545.JPG
#   inflating: all_dataset_fold_1/train/damaged/3282.JPG
#   inflating: all_dataset_fold_1/train/damaged/2987.JPG
#   inflating: all_dataset_fold_1/train/damaged/4515.JPG
#   inflating: all_dataset_fold_1/train/damaged/2542.JPG
#   inflating: all_dataset_fold_1/train/damaged/617.JPG
#   inflating: all_dataset_fold_1/train/damaged/3108.JPG
#   inflating: all_dataset_fold_1/train/damaged/1757.JPG
#   inflating: all_dataset_fold_1/train/damaged/2540.JPG
#   inflating: all_dataset_fold_1/train/damaged/3185.JPG
#   inflating: all_dataset_fold_1/train/damaged/1724.JPG
#   inflating: all_dataset_fold_1/train/damaged/2347.JPG
#   inflating: all_dataset_fold_1/train/damaged/2218.JPG
#   inflating: all_dataset_fold_1/train/damaged/2367.JPG
#   inflating: all_dataset_fold_1/train/damaged/1648.JPG
#   inflating: all_dataset_fold_1/train/damaged/2623.JPG
#   inflating: all_dataset_fold_1/train/damaged/3140.JPG
#   inflating: all_dataset_fold_1/train/damaged/3915.JPG
#   inflating: all_dataset_fold_1/train/damaged/2544.JPG
#   inflating: all_dataset_fold_1/train/damaged/2078.JPG
#   inflating: all_dataset_fold_1/train/damaged/4364.JPG
#   inflating: all_dataset_fold_1/train/damaged/2109.JPG
#   inflating: all_dataset_fold_1/train/damaged/5035.JPG
#   inflating: all_dataset_fold_1/train/damaged/1153.JPG
#   inflating: all_dataset_fold_1/train/damaged/3267.JPG
#   inflating: all_dataset_fold_1/train/damaged/2528.JPG
#   inflating: all_dataset_fold_1/train/damaged/1411.JPG
#   inflating: all_dataset_fold_1/train/damaged/2646.JPG
#   inflating: all_dataset_fold_1/train/damaged/2706.JPG
#   inflating: all_dataset_fold_1/train/damaged/2064.JPG
#   inflating: all_dataset_fold_1/train/damaged/3701.JPG
#   inflating: all_dataset_fold_1/train/damaged/4049.JPG
#   inflating: all_dataset_fold_1/train/damaged/3288.JPG
#   inflating: all_dataset_fold_1/train/damaged/4293.JPG
#   inflating: all_dataset_fold_1/train/damaged/2427.JPG
#   inflating: all_dataset_fold_1/train/damaged/2736.JPG
#   inflating: all_dataset_fold_1/train/damaged/2707.JPG
#   inflating: all_dataset_fold_1/train/damaged/2295.JPG
#   inflating: all_dataset_fold_1/train/damaged/2909.JPG
#   inflating: all_dataset_fold_1/train/damaged/3443.JPG
#   inflating: all_dataset_fold_1/train/damaged/2019.JPG
#   inflating: all_dataset_fold_1/train/damaged/2317.JPG
#   inflating: all_dataset_fold_1/train/damaged/1115.JPG
#   inflating: all_dataset_fold_1/train/damaged/1845.JPG
#   inflating: all_dataset_fold_1/train/damaged/3174.JPG
#   inflating: all_dataset_fold_1/train/damaged/1469.JPG
#   inflating: all_dataset_fold_1/train/damaged/3025.JPG
#   inflating: all_dataset_fold_1/train/damaged/1882.JPG
#   inflating: all_dataset_fold_1/train/damaged/3157.JPG
#   inflating: all_dataset_fold_1/train/damaged/3112.JPG
#   inflating: all_dataset_fold_1/train/damaged/1637.JPG
JPG
#   inflating: all_dataset_fold_1/validation/damaged/2305.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2033.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2677.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1633.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4449.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3326.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1830.JPG
#   inflating: all_dataset_fold_1/validation/damaged/602.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1948.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3928.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4145.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2908.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1836.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1417.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1282.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3002.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4193.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4319.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3436.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3296.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2711.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3894.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1923.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1916.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2338.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1623.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2920.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1412.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2303.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2874.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2126.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2885.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1750.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3249.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2870.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2277.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3264.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1901.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2744.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1266.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1837.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2821.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1245.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2835.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2526.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2799.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3999.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1753.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1481.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2124.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2447.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1519.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3362.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3320.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3776.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3790.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3584.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2675.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1642.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3277.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4569.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2633.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1241.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1394.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3093.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2985.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3439.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3156.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2879.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2990.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1679.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2824.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3676.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1662.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1787.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3259.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2696.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3590.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1195.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3050.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4155.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2434.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1800.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2420.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3106.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1962.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2469.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1383.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3087.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2165.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2892.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2772.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1710.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1902.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3190.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2314.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1729.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4339.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2127.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2590.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2285.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1327.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2935.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2748.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2380.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1177.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2970.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2531.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3344.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2611.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2578.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3979.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3067.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2667.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2154.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2818.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4250.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3768.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2042.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4023.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2069.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4508.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4724.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1782.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2568.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3495.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2313.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1969.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2918.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3479.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2791.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2694.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2615.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3638.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2553.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1579.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1442.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3381.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2395.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2393.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2660.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3019.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3798.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1523.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2980.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1849.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3654.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2816.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1844.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3057.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2523.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2082.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4372.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1547.JPG
#   inflating: all_dataset_fold_1/validation/damaged/5190.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2966.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2628.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2575.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3275.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2721.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4302.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1707.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3114.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2236.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3247.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2486.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1384.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3316.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1568.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3082.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3793.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2967.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3243.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3189.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1840.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2537.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1332.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1457.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2173.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3120.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3976.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1067.JPG
#   inflating: all_dataset_fold_1/validation/damaged/874.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2435.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2598.JPG
#   inflating: all_dataset_fold_1/validation/damaged/2525.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4973.JPG
#   inflating: all_dataset_fold_1/validation/damaged/4231.JPG
#   inflating: all_dataset_fold_1/validation/damaged/1343.JPG
#   inflating: all_dataset_fold_1/validation/damaged/3078.JPG

# %%
#imports

import tensorflow as tf

from tensorflow.keras.applications.efficientnet import EfficientNetB7,preprocess_input

#from tensorflow.keras.applications.nasnet import NASNetLarge, preprocess_input
from tensorflow.keras.layers import Input,GlobalMaxPooling2D,Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import img_to_array,load_img

import numpy as np
from cv2 import resize
from os import path, listdir

# %%
n_classes = 2

# %%
#set up MobileNet GlobalMaxPooling and unsepcified input resolution

inputs = Input(shape=(None,None,3))
#net = MobileNetV2(include_top=False, alpha=0.35, weights='imagenet', input_tensor=inputs, classes=n_classes)

net = EfficientNetB7(include_top=False, weights=None, input_tensor=inputs, classes=n_classes)

#net = NASNetLarge(include_top=False, weights='imagenet', input_tensor=inputs, classes=n_classes)
net = GlobalMaxPooling2D()(net.output)
outputs = Dense(n_classes,activation='softmax')(net)

model = Model(inputs=inputs,outputs=outputs)
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])

# %%
#data generator class; yields batches of data for training/testing
class ImageGenerator():

    def __init__(self, directory, batch_size=16, shuffle=False, max_dimension=None):        
        
        self.directories = directory
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.max_dimension = max_dimension
        
        self.image_paths = []
        self.class_labels = []
        
        #create list of image file paths and class target labels
        for class_label, class_dir in enumerate(listdir(directory)):
            self.image_paths += [path.join(directory,class_dir,f) for f in listdir(path.join(directory,class_dir))]
            self.class_labels += [class_label for _ in listdir(path.join(directory,class_dir))]

        self.image_paths = np.array(self.image_paths)
        self.class_labels = np.array(self.class_labels)

        #index array for shuffling data
        self.idx = np.arange(len(self.image_paths))
        
    
    def __len__(self):
        
        #number of batches in an epoch
        return int(np.ceil(len(self.image_paths)/float(self.batch_size)))
    
    
    def _load_image(self,img_path):
        
        #load image from path and convert to array
        img = load_img(img_path, color_mode='rgb', interpolation='nearest')
        img = img_to_array(img)
        
        #downsample image if above allowed size if specified
        max_dim = max(img.shape) 
        if self.max_dimension:
            if max_dim > self.max_dimension:
                new_dim = tuple(d*self.max_dimension//max_dim for d in img.shape[1::-1])
                img = resize(img, new_dim)
            
        #scale image values
        img = preprocess_input(img)

        return img
    
    
    def _pad_images(self,img,shape):
        #pad images to match largest image in batch
        img = np.pad(img,(*[((shape[i]-img.shape[i])//2,
                    ((shape[i]-img.shape[i])//2) + ((shape[i]-img.shape[i])%2)) for i in range(2)],
                          (0,0)),mode='constant',constant_values=0.)
        
        return img


    def __call__(self):
        #shuffle index
        if self.shuffle:
            np.random.shuffle(self.idx)
        
        #generate batches
        for batch in range(len(self)):

            batch_image_paths = self.image_paths[self.idx[batch*self.batch_size:(batch+1)*self.batch_size]]
            batch_class_labels = self.class_labels[self.idx[batch*self.batch_size:(batch+1)*self.batch_size]]

            batch_images = [self._load_image(image_path) for image_path in batch_image_paths]

            max_resolution = tuple(max([img.shape[i] for img in batch_images]) for i in range(2))
            batch_images = np.array([self._pad_images(image,max_resolution) for image in batch_images])

            yield batch_images, batch_class_labels

# %%
#model.load_weights('insulators-v17.h5')

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
#initialize our generators; specifying data directories, batch size, and dimension threshold

train_image_directory = 'all_dataset_fold_1/train'
test_image_directory = 'all_dataset_fold_1/validation'

#n_classes = 10
batch_size = 1
max_dimension = 512

#create generators for training and generating

train_generator = ImageGenerator(train_image_directory, batch_size=batch_size, shuffle=True, max_dimension=max_dimension)
test_generator = ImageGenerator(test_image_directory, batch_size=batch_size, max_dimension=max_dimension)

#convert generators into tf.data.Dataset objects for optimization with keras model fit method

train_dataset = tf.data.Dataset.from_generator(train_generator,
     (tf.float32, tf.int32),
    (tf.TensorShape([None,None,None,3]), tf.TensorShape([None])))

test_dataset = tf.data.Dataset.from_generator(test_generator,
     (tf.float32, tf.int32),
    (tf.TensorShape([None,None,None,3]), tf.TensorShape([None])))


#train and evaluate model
history = model.fit(train_dataset,validation_data=test_dataset,epochs=100,verbose=1,workers=2,max_queue_size=20, callbacks=[callback])
# Out:
# Epoch 1/100
# 3402/3402 [==============================] - 745s 219ms/step - loss: nan - sparse_categorical_accuracy: 0.6670 - val_loss: nan - val_sparse_categorical_accuracy: 0.6663
# Epoch 2/100
# 3402/3402 [==============================] - 741s 218ms/step - loss: nan - sparse_categorical_accuracy: 0.6670 - val_loss: nan - val_sparse_categorical_accuracy: 0.6663
# Epoch 3/100
# 3402/3402 [==============================] - ETA: 0s - loss: nan - sparse_categorical_accuracy: 0.6670
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-8cb56824fce4> in <module>()
#      25
#      26 #train and evaluate model
# ---> 27 history = model.fit(train_dataset,validation_data=test_dataset,epochs=100,verbose=1,workers=2,max_queue_size=20, callbacks=[callback])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1135           epoch_logs.update(val_logs)
#    1136
# -> 1137         callbacks.on_epoch_end(epoch, epoch_logs)
#    1138         training_logs = epoch_logs
#    1139         if self.stop_training:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     414         if numpy_logs is None:  # Only convert once.
#     415           numpy_logs = tf_utils.to_numpy_or_python_type(logs)
# --> 416         callback.on_epoch_end(epoch, numpy_logs)
#     417
#     418   def on_train_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#    1675           if self.verbose > 0:
#    1676             print('Restoring model weights from the end of the best epoch.')
# -> 1677           self.model.set_weights(self.best_weights)
#    1678
#    1679   def on_train_end(self, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in set_weights(self, weights)
#    1803         expected_num_weights += 1
#    1804
# -> 1805     if expected_num_weights != len(weights):
#    1806       raise ValueError(
#    1807           'You called `set_weights(weights)` on layer "%s" '
#
# TypeError: object of type 'NoneType' has no len()

# %%
# Save the entire model to a HDF5 file
model.save('eff_fold_1.h5')

# %% [markdown]
# Visualize

# %%
import matplotlib.pyplot as plt

# %%
acc = history.history['sparse_categorical_accuracy']
val_acc = history.history['val_sparse_categorical_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(12)

plt.figure(figsize=(25, 8))
plt.subplot(1, 2, 1)


#plt.plot(epochs_range, acc, label='Training Accuracy')
#plt.plot(epochs_range, val_acc, label='Validation Accuracy')

plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')


plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
#plt.plot(epochs_range, loss, label='Training Loss')
#plt.plot(epochs_range, val_loss, label='Validation Loss')


plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')

plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Evaluation

# %%
test_loss, test_acc = model.evaluate_generator(test_dataset, verbose=0)

#test_loss, test_acc = model.evaluate_generator(test_data_gen, verbose=0)

print('\nTest accuracy:', test_acc)



print('\nTest accuracy:', test_acc)

print('\nTest loss:', test_loss)

# %%
## Make predictions on test data ##

### Let's make predictions on some images ###

test_generator.class_labels

predictions = model.predict_generator(test_dataset)

true_labels = test_generator.class_labels

predictions[0]

np.argmax(predictions[0])

test_generator.class_labels[0]

predictions[-1]

np.argmax(predictions[-1])

test_generator.class_labels[-1]



#test_dataset.classes

# %%
type(test_dataset)

# %%
#test_generator.image_paths

# %%
test_generator.class_labels

# %%
## Confusion Matrix ##

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np



y_true = true_labels
y_pred = np.array([np.argmax(x) for x in predictions])

y_pred





cm = confusion_matrix(y_true, y_pred)

print(cm)



plt.matshow(cm, cmap=plt.cm.gray)
plt.show()

# %%
y_pred

# %%
from sklearn.metrics import classification_report

# %%
target_names = ['undamaged', 'damaged']
print(classification_report(y_true, y_pred, target_names=target_names))

# %% [markdown]
# ## ROC-AUC ##

# %%
from sklearn.metrics import auc, roc_curve, roc_auc_score

fpr, tpr, _ = roc_curve(y_true, y_pred)
roc_auc = auc(fpr, tpr)

print(roc_auc)

# %%
#train and evaluate model
#model.fit(train_dataset,epochs=10,verbose=1,workers=2,max_queue_size=20)
