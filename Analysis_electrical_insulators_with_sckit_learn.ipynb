# %% [markdown]
# <a href="https://colab.research.google.com/github/demolakstate/AdeNet-Deep-Learning-Architecture/blob/main/Analysis_electrical_insulators_with_sckit_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
pwd
# Out:
# '/content'

# %%
ls sample_data/
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
from pandas import DataFrame, read_csv
import pandas as pd

df=pd.read_csv('dataset.csv')
df=df.drop(['Path'],axis=1)

# %%
df.head()
# Out:
#      Class  ...  max (Edge Wavelet Transform)
# 0  damaged  ...                       227.243
# 1  damaged  ...                       205.956
# 2  damaged  ...                       186.297
# 3  damaged  ...                       213.510
# 4  damaged  ...                       207.774
#
# [5 rows x 2899 columns]

# %%
df.tail()
# Out:
#           Class  ...  max (Edge Wavelet Transform)
# 1680  undamaged  ...                       177.394
# 1681  undamaged  ...                       207.599
# 1682  undamaged  ...                       204.065
# 1683  undamaged  ...                       191.254
# 1684  undamaged  ...                       233.911
#
# [5 rows x 2899 columns]

# %%
from sklearn.utils import shuffle
df = shuffle(df)

# %%
df.head()

# %%
df.tail()

# %%
test=df.iloc[:300,:]
train=df.iloc[300:,:]


train_labels=train['Class'].tolist()
train=train.drop(['Class'],axis=1)
train_samples=train.values.tolist()

test_labels=test['Class'].tolist()
test=test.drop(['Class'],axis=1)
test_samples=test.values.tolist()

# %%
for i in range (len(train_labels)):
  if train_labels[i]=='damaged':
    train_labels[i]=0
  if train_labels[i]=='undamaged':
    train_labels[i]=1

for i in range (len(test_labels)):
  if test_labels[i]=='damaged':
    test_labels[i]=0
  if test_labels[i]=='undamaged':
    test_labels[i]=1

# %%
classifiers = [
KNeighborsClassifier(3),
SVC(kernel="rbf", C=0.025, probability=True),
#SVC(kernel="sigmoid", C=0.025, probability=True),
#NuSVC(probability=True),
DecisionTreeClassifier(),
RandomForestClassifier(),
AdaBoostClassifier(),
GradientBoostingClassifier(),
GaussianNB(),
LinearDiscriminantAnalysis(),
QuadraticDiscriminantAnalysis()]

for clf in classifiers:
  clf.fit(train_samples, train_labels)
  res=clf.predict(test_samples)
  acc = accuracy_score(test_labels, res)
  print (clf.__class__.__name__+" Accuracy: "+str(acc))

correct_samples=0
for i in range (len(test_labels)):
  if test_labels[i]==res[i]:
     correct_samples=correct_samples+1
print(correct_samples/len(test_labels))
# Out:
# KNeighborsClassifier Accuracy: 0.6233333333333333
# SVC Accuracy: 0.7
# DecisionTreeClassifier Accuracy: 0.7866666666666666
# RandomForestClassifier Accuracy: 0.8333333333333334
# AdaBoostClassifier Accuracy: 0.8333333333333334
# GradientBoostingClassifier Accuracy: 0.8533333333333334
# GaussianNB Accuracy: 0.49666666666666665
# LinearDiscriminantAnalysis Accuracy: 0.7133333333333334
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# QuadraticDiscriminantAnalysis Accuracy: 0.5933333333333334
# 0.5933333333333334
